# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.applications.inception_v3 import decode_predictions
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import image
import numpy as np
import os 
from os import listdir
from PIL import Image as PImage

# %%
img_width,img_height=299,299

# %%
model_pretrained=InceptionV3(weights="imagenet",include_top=True,input_shape=(img_height,img_width,3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 1100s 11us/step

# %%
img_path=("C:\\Users\\HP\\Pictures\\Saved Pictures\\1.jpg")

# %%
img= image.load_img(img_path,target_size=(img_width,img_height))

# %%
img_data=image.img_to_array(img)

# %%
img_data=np.expand_dims(img_data,axis=0)

# %%
img_data=preprocess_input(img_data)

# %%
cnn_feature=model_pretrained.predict(img_data)

# %%
label=decode_predictions(cnn_feature)

# %%
label=label[0][0]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)


stringprint = "%.1f" % round(label[2]*100,1)
plt.title(label[1] + " " + str(stringprint) + "%", fontsize=20)
plt.axis("off")
plt.show()
